# %%
import altair as alt
import pandas as pd


total = [
    {"node_id": 0, "gpu_mem_mb": 1738.69}, # before forwarding.
    {"node_id": 1, "gpu_mem_mb": 6755.65},
    {"node_id": 2, "gpu_mem_mb": 10043.98},
    {"node_id": 3, "gpu_mem_mb": 9632.94},
    {"node_id": 4, "gpu_mem_mb": 12099.19},
    {"node_id": 5, "gpu_mem_mb": 13743.36},
    {"node_id": 6, "gpu_mem_mb": 13537.84},
    {"node_id": 7, "gpu_mem_mb": 14770.97},
    {"node_id": 8, "gpu_mem_mb": 15593.05},
    {"node_id": 9, "gpu_mem_mb": 16415.14},
    {"node_id":10, "gpu_mem_mb": 17237.22},
    {"node_id":11, "gpu_mem_mb": 17134.46},
    {"node_id":12, "gpu_mem_mb": 17751.03},
    {"node_id":13, "gpu_mem_mb": 18162.08},
    {"node_id":14, "gpu_mem_mb": 18573.12},
    {"node_id":15, "gpu_mem_mb": 18984.17},
    {"node_id":16, "gpu_mem_mb": 18932.79},
    {"node_id":17, "gpu_mem_mb": 19086.93},
    {"node_id":18, "gpu_mem_mb": 19189.70},
    {"node_id":19, "gpu_mem_mb": 19292.46},
    {"node_id":20, "gpu_mem_mb": 19395.23},
    {"node_id":21, "gpu_mem_mb": 19382.38},
]

wgm = 3*548 # weight + gradient + momentum
algo_predict = [
    {"node_id": 0, "gpu_mem_mb": wgm }, # before forwarding.
    {"node_id": 1, "gpu_mem_mb": wgm+1568 },
    {"node_id": 2, "gpu_mem_mb": wgm+1568 },
    {"node_id": 3, "gpu_mem_mb": wgm+392 }, # pivot 1
    {"node_id": 4, "gpu_mem_mb": wgm+(392)+784 },
    {"node_id": 5, "gpu_mem_mb": wgm+(392)+784 },
    {"node_id": 6, "gpu_mem_mb": wgm+(392)+196 }, # pivot 2
    {"node_id": 7, "gpu_mem_mb": wgm+(392)+(196)+392 },
    {"node_id": 8, "gpu_mem_mb": wgm+(392)+(196)+392 },
    {"node_id": 9, "gpu_mem_mb": wgm+(392)+(196)+392 },
    {"node_id":10, "gpu_mem_mb": wgm+(392)+(196)+392 },
    {"node_id":11, "gpu_mem_mb": wgm+(392)+(196)+98 },
    {"node_id":12, "gpu_mem_mb": wgm+(392)+(196)+196 },
    {"node_id":13, "gpu_mem_mb": wgm+(392)+(196)+196 },
    {"node_id":14, "gpu_mem_mb": wgm+(392)+(196)+196 },
    {"node_id":15, "gpu_mem_mb": wgm+(392)+(196)+196 },
    {"node_id":16, "gpu_mem_mb": wgm+(392)+(196)+49 },
    {"node_id":17, "gpu_mem_mb": wgm+(392)+(196)+49 },
    {"node_id":18, "gpu_mem_mb": wgm+(392)+(196)+49 },
    {"node_id":19, "gpu_mem_mb": wgm+(392)+(196)+49 },
    {"node_id":20, "gpu_mem_mb": wgm+(392)+(196)+49 },
    {"node_id":21, "gpu_mem_mb": wgm+(392)+(196)+12 },
    {"node_id":22, "gpu_mem_mb": wgm+(392)+(196)+2 }, # C1
    {"node_id":23, "gpu_mem_mb": wgm+(392)+(196)+2 }, # C2
    {"node_id":24, "gpu_mem_mb": wgm+(392)+(196)+0.48 }, # C3

    {"node_id":25, "gpu_mem_mb": wgm+(392)+(196)+0.48 }, # since size(output)=size(target).
    
    {"node_id":26, "gpu_mem_mb": wgm+(392)+(196)+2711.48 }, # C3
    {"node_id":27, "gpu_mem_mb": wgm+(392)+(196)+2711.48 }, # C2
    {"node_id":28, "gpu_mem_mb": wgm+(392)+(196)+2711.48 }, # C1
    {"node_id":29, "gpu_mem_mb": wgm+(392)+(196)+2711.48 }, # pivot 3
    {"node_id":30, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":31, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":32, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":33, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":34, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":35, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":36, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":37, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":38, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":39, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":40, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":41, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":42, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":43, "gpu_mem_mb": wgm+(392)+(196)+2711.48 },
    {"node_id":44, "gpu_mem_mb": wgm+(392)+(196) }, # pivot 2
    {"node_id":45, "gpu_mem_mb": wgm+(392)+(196)+1568},
    {"node_id":46, "gpu_mem_mb": wgm+(392)+(196)+1568},
    {"node_id":47, "gpu_mem_mb": wgm+(392)+(196) }, # pivot 1
    {"node_id":48, "gpu_mem_mb": wgm+(392)+(196)+3136 },
    {"node_id":49, "gpu_mem_mb": wgm+(392)+(196)+3136 },
    {"node_id":50, "gpu_mem_mb": wgm }, # all done.
]
for i, v in enumerate(algo_predict):
    print('{}-th node, {}MB'.format(i, v['gpu_mem_mb']))


total_cp_algo = [
    {"node_id": 0, "gpu_mem_mb": 1739.89 }, # before forwarding.
    {"node_id": 1, "gpu_mem_mb": 3307.89 },
    {"node_id": 2, "gpu_mem_mb": 3307.89 },
    {"node_id": 3, "gpu_mem_mb": 2131.89 }, # pivot 1
    {"node_id": 4, "gpu_mem_mb": 2915.89 },
    {"node_id": 5, "gpu_mem_mb": 2915.89 },
    {"node_id": 6, "gpu_mem_mb": 2327.89 }, # pivot 2
    {"node_id": 7, "gpu_mem_mb": 2719.89 },
    {"node_id": 8, "gpu_mem_mb": 2719.89 },
    {"node_id": 9, "gpu_mem_mb": 2719.89 },
    {"node_id":10, "gpu_mem_mb": 2719.89 },
    {"node_id":11, "gpu_mem_mb": 2425.89 }, # maxpool
    {"node_id":12, "gpu_mem_mb": 2523.89 },
    {"node_id":13, "gpu_mem_mb": 2523.89 },
    {"node_id":14, "gpu_mem_mb": 2523.89 },
    {"node_id":15, "gpu_mem_mb": 2523.89 },
    {"node_id":16, "gpu_mem_mb": 2376.89 }, # maxpool
    {"node_id":17, "gpu_mem_mb": 2376.89 },
    {"node_id":18, "gpu_mem_mb": 2376.89 },
    {"node_id":19, "gpu_mem_mb": 2376.89 },
    {"node_id":20, "gpu_mem_mb": 2376.89 },
    {"node_id":21, "gpu_mem_mb": 2340.14 }, # maxpool
    {"node_id":22, "gpu_mem_mb": 2329.89 }, # C1
    {"node_id":23, "gpu_mem_mb": 2329.89 }, # C2
    {"node_id":24, "gpu_mem_mb": 2328.38 }, # C3

    {"node_id":25, "gpu_mem_mb": 2328.38 }, # 
    
    {"node_id":26, "gpu_mem_mb": 5359.23 }, # C3
    {"node_id":27, "gpu_mem_mb": 5359.23 }, # C2
    {"node_id":28, "gpu_mem_mb": 5359.23 }, # C1
    {"node_id":29, "gpu_mem_mb": 5359.23 }, # diff=5358-4943=415
    {"node_id":30, "gpu_mem_mb": 5359.23 },
    {"node_id":31, "gpu_mem_mb": 5359.23 },
    {"node_id":32, "gpu_mem_mb": 5359.23 },
    {"node_id":33, "gpu_mem_mb": 5359.23 },
    {"node_id":34, "gpu_mem_mb": 5359.23 },
    {"node_id":35, "gpu_mem_mb": 5359.23 },
    {"node_id":36, "gpu_mem_mb": 5359.23 },
    {"node_id":37, "gpu_mem_mb": 5359.23 },
    {"node_id":38, "gpu_mem_mb": 5359.23 },
    {"node_id":39, "gpu_mem_mb": 5359.23 },
    {"node_id":40, "gpu_mem_mb": 5359.23 },
    {"node_id":41, "gpu_mem_mb": 5359.23 },
    {"node_id":42, "gpu_mem_mb": 5359.23 },
    {"node_id":43, "gpu_mem_mb": 5359.23 },
    {"node_id":44, "gpu_mem_mb": 2328.38 }, # pivot 2
    {"node_id":45, "gpu_mem_mb": 4484.38 }, # diff 4486.64-3800=686.64
    {"node_id":46, "gpu_mem_mb": 4484.38 },
    {"node_id":47, "gpu_mem_mb": 2132.38 }, # pivot 1
    {"node_id":48, "gpu_mem_mb": 6444.38 }, # TODO: upda
    {"node_id":49, "gpu_mem_mb": 6444.38 },
    {"node_id":50, "gpu_mem_mb": 1740.38 }, # all done.
]
# print([ n['gpu_mem_mb'] for n in total_cp_algo])

total_cp_na = [
    {"node_id": 0, "gpu_mem_mb": 1681.824218}, # before forwarding.
    {"node_id": 1, "gpu_mem_mb": 5111.09},
    {"node_id": 2, "gpu_mem_mb": 3466.92},
    {"node_id": 3, "gpu_mem_mb": 3877.96},
    {"node_id": 4, "gpu_mem_mb": 5111.09},
    {"node_id": 5, "gpu_mem_mb": 4289.00},
    {"node_id": 6, "gpu_mem_mb": 4494.52},
    {"node_id": 7, "gpu_mem_mb": 5111.09},
    {"node_id": 8, "gpu_mem_mb": 4700.04},
    {"node_id": 9, "gpu_mem_mb": 5522.13},
    {"node_id":10, "gpu_mem_mb": 5522.13},
    {"node_id":11, "gpu_mem_mb": 4802.80},
    {"node_id":12, "gpu_mem_mb": 5213.85},
    {"node_id":13, "gpu_mem_mb": 5008.33},
    {"node_id":14, "gpu_mem_mb": 5419.37},
    {"node_id":15, "gpu_mem_mb": 5419.37},
    {"node_id":16, "gpu_mem_mb": 5059.71},
    {"node_id":17, "gpu_mem_mb": 5162.47},
    {"node_id":18, "gpu_mem_mb": 5111.09},
    {"node_id":19, "gpu_mem_mb": 5213.85},
    {"node_id":20, "gpu_mem_mb": 5213.85},
    {"node_id":21, "gpu_mem_mb": 5124.32},
]

# Prediction by algo.
# [1568, 1568, 392.0,
#  784.0, 784.0, 196.0,
#  392.0, 392.0, 392.0, 392.0,
#  98.0, 196.0, 196.0, 196.0, 196.0,
#  49.0, 49.0, 49.0, 49.0, 49.0, 12.0]
# + weight_all.
# 547.990966796875 MB = 76.365966796875 MB (conv) + ? MB (classifier)
# pytorch_memlab:
# Used Memory: 548.05M  Total Tensors: 143667240        

df_total = pd.DataFrame(total)
df_total_cp_algo = pd.DataFrame(total_cp_algo)
df_total_cp_na = pd.DataFrame(total_cp_na)
df_algo_predict = pd.DataFrame(algo_predict)
# df_activation = pd.DataFrame(activation)

l_total = alt.Chart(df_total).mark_line(color="#7d8597").transform_fold(
    ['gpu_mem_mb']
).encode(
    alt.X("node_id", axis=alt.Axis(tickMinStep=1)).title("Node ID"),
    alt.Y("gpu_mem_mb", axis=alt.Axis(tickMinStep=100)).title("GPU Memory(MB)"),
)


l_total_cp_algo = alt.Chart(df_total_cp_algo).mark_line(color="#0ead69").transform_fold(
    ['gpu_mem_mb']
).encode(
    alt.X("node_id", axis=alt.Axis(tickMinStep=1)).title("Node ID"),
    alt.Y("gpu_mem_mb", axis=alt.Axis(tickMinStep=100)).title("GPU Memory(MB)"),
)


l_total_cp_na = alt.Chart(df_total_cp_na).mark_line(color="#7678ed").transform_fold(
    ['gpu_mem_mb']
).encode(
    alt.X("node_id", axis=alt.Axis(tickMinStep=1)).title("Node ID"),
    alt.Y("gpu_mem_mb", axis=alt.Axis(tickMinStep=100)).title("GPU Memory(MB)"),
)


l_algo_predict = alt.Chart(df_algo_predict).mark_line(color="#7678ed").transform_fold(
    ['gpu_mem_mb']
).encode(
    alt.X("node_id", axis=alt.Axis(tickMinStep=1)).title("Node ID"),
    alt.Y("gpu_mem_mb", axis=alt.Axis(tickMinStep=100)).title("GPU Memory(MB)"),
)

# y_segment_cost = (
#     alt.Chart().mark_rule(strokeDash=[12, 6], size=2).encode(y=alt.datum(822))
# )

# bar = line.mark_bar()
point_total = l_total.mark_point(color="#333")
point_total_cp_algo = l_total_cp_algo.mark_point(color="#333")
point_total_cp_na = l_total_cp_na.mark_point(color="#333")
point_algo_predict = l_algo_predict.mark_point(color="#333")

(l_total_cp_algo + point_total_cp_algo
 # + l_total_cp_na + point_total_cp_na
 # + l_total + point_total
 + l_algo_predict + point_algo_predict
).transform_fold(
    ['gpu_mem_mb'],
).properties(
    title="GPU Memory Usage: VGG19 with Gradient-Checkpointing Enabled",
    width=1500,
    height=900
)
# Out:
# 0-th node, 1644MB
# 1-th node, 3212MB
# 2-th node, 3212MB
# 3-th node, 2036MB
# 4-th node, 2820MB
# 5-th node, 2820MB
# 6-th node, 2232MB
# 7-th node, 2624MB
# 8-th node, 2624MB
# 9-th node, 2624MB
# 10-th node, 2624MB
# 11-th node, 2330MB
# 12-th node, 2428MB
# 13-th node, 2428MB
# 14-th node, 2428MB
# 15-th node, 2428MB
# 16-th node, 2281MB
# 17-th node, 2281MB
# 18-th node, 2281MB
# 19-th node, 2281MB
# 20-th node, 2281MB
# 21-th node, 2244MB
# 22-th node, 2234MB
# 23-th node, 2234MB
# 24-th node, 2232.48MB
# 25-th node, 2232.48MB
# 26-th node, 4943.48MB
# 27-th node, 4943.48MB
# 28-th node, 4943.48MB
# 29-th node, 4943.48MB
# 30-th node, 4943.48MB
# 31-th node, 4943.48MB
# 32-th node, 4943.48MB
# 33-th node, 4943.48MB
# 34-th node, 4943.48MB
# 35-th node, 4943.48MB
# 36-th node, 4943.48MB
# 37-th node, 4943.48MB
# 38-th node, 4943.48MB
# 39-th node, 4943.48MB
# 40-th node, 4943.48MB
# 41-th node, 4943.48MB
# 42-th node, 4943.48MB
# 43-th node, 4943.48MB
# 44-th node, 2232MB
# ...
