# %%
import altair as alt
import pandas as pd


total = [
    {"node_id": 0, "gpu_mem_mb": 1739}, # before forwarding.
    {"node_id": 1, "gpu_mem_mb": 3307},
    {"node_id": 2, "gpu_mem_mb": 4875},
    {"node_id": 3, "gpu_mem_mb": 6051}, # M
    {"node_id": 4, "gpu_mem_mb": 6835},
    {"node_id": 5, "gpu_mem_mb": 7619},
    {"node_id": 6, "gpu_mem_mb": 8207}, # M
    {"node_id": 7, "gpu_mem_mb": 8599},
    {"node_id": 8, "gpu_mem_mb": 8991},
    {"node_id": 9, "gpu_mem_mb": 9383},
    {"node_id":10, "gpu_mem_mb": 9775},
    {"node_id":11, "gpu_mem_mb": 10069}, # M
    {"node_id":12, "gpu_mem_mb": 10265},
    {"node_id":13, "gpu_mem_mb": 10461},
    {"node_id":14, "gpu_mem_mb": 10657},
    {"node_id":15, "gpu_mem_mb": 10853},
    {"node_id":16, "gpu_mem_mb": 11000}, # M
    {"node_id":17, "gpu_mem_mb": 11049},
    {"node_id":18, "gpu_mem_mb": 11098},
    {"node_id":19, "gpu_mem_mb": 11147},
    {"node_id":20, "gpu_mem_mb": 11196},
    {"node_id":21, "gpu_mem_mb": 11233}, # M
    {"node_id":22, "gpu_mem_mb": 11235}, # C1
    {"node_id":23, "gpu_mem_mb": 11237}, # C2
    {"node_id":24, "gpu_mem_mb": 11237}, # C3
    
    {"node_id":25, "gpu_mem_mb": 11238}, # after forward, before backward.
    
    {"node_id":26, "gpu_mem_mb": 11240},
    {"node_id":27, "gpu_mem_mb": 11240},
    {"node_id":28, "gpu_mem_mb": 11236},
    {"node_id":29, "gpu_mem_mb": 11258}, # M
    {"node_id":30, "gpu_mem_mb": 11246},
    {"node_id":31, "gpu_mem_mb": 11197},
    {"node_id":32, "gpu_mem_mb": 11148},
    {"node_id":33, "gpu_mem_mb": 11050},
    {"node_id":34, "gpu_mem_mb": 11099}, # M
    {"node_id":35, "gpu_mem_mb": 11050},
    {"node_id":36, "gpu_mem_mb": 10854},
    {"node_id":37, "gpu_mem_mb": 10658},
    {"node_id":38, "gpu_mem_mb": 10266},
    {"node_id":39, "gpu_mem_mb": 10266},
    {"node_id":40, "gpu_mem_mb": 10168},
    {"node_id":41, "gpu_mem_mb": 9776},
    {"node_id":42, "gpu_mem_mb": 9384},
    {"node_id":43, "gpu_mem_mb": 8600},
    {"node_id":44, "gpu_mem_mb": 8208}, # down after segment
    {"node_id":45, "gpu_mem_mb": 8600},
    {"node_id":46, "gpu_mem_mb": 8600},
    {"node_id":47, "gpu_mem_mb": 7032},
    {"node_id":48, "gpu_mem_mb": 7032}, # M
    {"node_id":49, "gpu_mem_mb": 6640}, # down after segment
    {"node_id":50, "gpu_mem_mb": 6444},
    {"node_id":51, "gpu_mem_mb": 3308},
    {"node_id":52, "gpu_mem_mb": 1740},
]

wgm = 3*548 # weight + gradient + momentum
algo_predict = [
    {"node_id": 0, "gpu_mem_mb": wgm }, # before forwarding.
    {"node_id": 1, "gpu_mem_mb": wgm+1568 },
    {"node_id": 2, "gpu_mem_mb": wgm+(1568) }, # pivot 1
    {"node_id": 3, "gpu_mem_mb": wgm+(1568)+392 },
    {"node_id": 4, "gpu_mem_mb": wgm+(1568)+784 },
    {"node_id": 5, "gpu_mem_mb": wgm+(1568)+784 },
    {"node_id": 6, "gpu_mem_mb": wgm+(1568)+(196) }, # pivot 2
    {"node_id": 7, "gpu_mem_mb": wgm+(1568)+(196)+392 },
    {"node_id": 8, "gpu_mem_mb": wgm+(1568)+(196)+392 },
    {"node_id": 9, "gpu_mem_mb": wgm+(1568)+(196)+392 },
    {"node_id":10, "gpu_mem_mb": wgm+(1568)+(196)+392 },
    {"node_id":11, "gpu_mem_mb": wgm+(1568)+(196)+98 },
    {"node_id":12, "gpu_mem_mb": wgm+(1568)+(196)+196 },
    {"node_id":13, "gpu_mem_mb": wgm+(1568)+(196)+196 },
    {"node_id":14, "gpu_mem_mb": wgm+(1568)+(196)+196 },
    {"node_id":15, "gpu_mem_mb": wgm+(1568)+(196)+196 },
    {"node_id":16, "gpu_mem_mb": wgm+(1568)+(196)+49 },
    {"node_id":17, "gpu_mem_mb": wgm+(1568)+(196)+49 },
    {"node_id":18, "gpu_mem_mb": wgm+(1568)+(196)+49 },
    {"node_id":19, "gpu_mem_mb": wgm+(1568)+(196)+49 },
    {"node_id":20, "gpu_mem_mb": wgm+(1568)+(196)+49 },
    {"node_id":21, "gpu_mem_mb": wgm+(1568)+(196)+12 },
    {"node_id":22, "gpu_mem_mb": wgm+(1568)+(196)+2 }, # C1
    {"node_id":23, "gpu_mem_mb": wgm+(1568)+(196)+2 }, # C2
    {"node_id":24, "gpu_mem_mb": wgm+(1568)+(196)+(0.48) }, # C3

    {"node_id":25, "gpu_mem_mb": wgm+(1568)+(196)+(0.48) }, # since size(output)=size(target).
    
    {"node_id":26, "gpu_mem_mb": wgm+(1568)+(196)+(0.48) }, # checkpoint, C3 +3103=2711+ 392, 已有考慮最大 output gradient
    {"node_id":27, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48) }, # C2
    {"node_id":28, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2) }, # C1
    {"node_id":29, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2) }, # M
    {"node_id":30, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12) },
    {"node_id":31, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*1) },
    {"node_id":32, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*2) },
    {"node_id":33, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*4) }, # * 可否再低？
    {"node_id":34, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*4) }, # M        *
    {"node_id":35, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*4+49) }, #    *
    {"node_id":36, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*4+49+196) }, #    *
    {"node_id":37, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*4+49+196*2) }, #    *
    {"node_id":38, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*4+49+196*4) }, #    *
    {"node_id":39, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(0.48+2*2+12+49*4+49+196*4) }, # M  *
    {"node_id":40, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(2*2+12.25+49*4+49+196*4+98) },
    {"node_id":41, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(2*2+12.25+49*4+49+196*4+98+392) },
    {"node_id":42, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(2*2+12.25+49*4+49+196*4+98+392*2) },
    {"node_id":43, "gpu_mem_mb": wgm+(1568)+(196)+(2711.48+392)-(2*2+12.25+49*4+49+196*4+98+392*3       +392) }, # 圖中最低值
    {"node_id":44, "gpu_mem_mb": wgm+(1568)+(196) }, # after segment.
    
         #   (weight + grad_weight + momentum) + (ckpts) + (re-forward(l,r] + max-of-seg[l,r]-for-output-gradient) - (rhs-data + ...-for-output-gradient)
    {"node_id":45, "gpu_mem_mb": wgm+(1568)+(392+784*2+196+1568) },                          # M 196       峰值
    {"node_id":46, "gpu_mem_mb": wgm+(1568)+(392+784*2+196+1568)-(784) },                    # 784         峰值
    {"node_id":47, "gpu_mem_mb": wgm+(1568)+(392+784*2+196+1568)-(784*2) },                  # 784 ＊
    {"node_id":48, "gpu_mem_mb": wgm+(1568)+(392+784*2+196+1568)-(784*2       +1568) },      # M 392 ＊
    {"node_id":49, "gpu_mem_mb": wgm+(1568) }, # after segment.
    
    {"node_id":50, "gpu_mem_mb": wgm+(1568*2+1568) }, # pivot 1 +3136=1568+ 1568
    {"node_id":51, "gpu_mem_mb": wgm+(1568*2+1568)-(1568      +1568) }, # first layer of segment.
    
    {"node_id":52, "gpu_mem_mb": wgm }, # all done.
]
for i, v in enumerate(algo_predict):
    print('{}-th node, {}MB'.format(i, v['gpu_mem_mb']))


total_cp_algo = [
    {"node_id": 0, "gpu_mem_mb": 1739 }, # before forwarding.
    {"node_id": 1, "gpu_mem_mb": 3307 },
    {"node_id": 2, "gpu_mem_mb": 3307 }, # pivot 1
    {"node_id": 3, "gpu_mem_mb": 3699 }, # (maxpool2d) +392=392
    {"node_id": 4, "gpu_mem_mb": 4091 },
    {"node_id": 5, "gpu_mem_mb": 4091 },
    {"node_id": 6, "gpu_mem_mb": 3503 }, # pivot 2 (maxpool2d) +588=784-196 (=392+196)
    {"node_id": 7, "gpu_mem_mb": 3895 },
    {"node_id": 8, "gpu_mem_mb": 3895 },
    {"node_id": 9, "gpu_mem_mb": 3895 },
    {"node_id":10, "gpu_mem_mb": 3895 },
    {"node_id":11, "gpu_mem_mb": 3601 }, # (maxpool2d) +294=392-98
    {"node_id":12, "gpu_mem_mb": 3699 },
    {"node_id":13, "gpu_mem_mb": 3699 },
    {"node_id":14, "gpu_mem_mb": 3699 },
    {"node_id":15, "gpu_mem_mb": 3699 },
    {"node_id":16, "gpu_mem_mb": 3552 }, # (maxpool2d) 147=196-49
    {"node_id":17, "gpu_mem_mb": 3552 },
    {"node_id":18, "gpu_mem_mb": 3552 },
    {"node_id":19, "gpu_mem_mb": 3552 },
    {"node_id":20, "gpu_mem_mb": 3552 },
    {"node_id":21, "gpu_mem_mb": 3515 }, # (maxpool2d) 49-12=37
    {"node_id":22, "gpu_mem_mb": 3505 }, # C1
    {"node_id":23, "gpu_mem_mb": 3505 }, # C2
    {"node_id":24, "gpu_mem_mb": 3503 }, # C3

    {"node_id":25, "gpu_mem_mb": 3504 }, # 
    
    {"node_id":26, "gpu_mem_mb": 3505 }, # C3
    {"node_id":27, "gpu_mem_mb": 6537 }, # C2
    {"node_id":28, "gpu_mem_mb": 6532 }, # C1
    {"node_id":29, "gpu_mem_mb": 6555 }, # (maxpool2d)
    {"node_id":30, "gpu_mem_mb": 6543 },
    {"node_id":31, "gpu_mem_mb": 6494 },
    {"node_id":32, "gpu_mem_mb": 6445 },
    {"node_id":33, "gpu_mem_mb": 6347 },
    {"node_id":34, "gpu_mem_mb": 6395 }, # M
    {"node_id":35, "gpu_mem_mb": 6346 },
    {"node_id":36, "gpu_mem_mb": 6150 },
    {"node_id":37, "gpu_mem_mb": 5954 },
    {"node_id":38, "gpu_mem_mb": 5562 },
    {"node_id":39, "gpu_mem_mb": 5562 }, # M
    {"node_id":40, "gpu_mem_mb": 5464 },
    {"node_id":41, "gpu_mem_mb": 5072 },
    {"node_id":42, "gpu_mem_mb": 4680 },
    {"node_id":43, "gpu_mem_mb": 3896 },
    
    {"node_id":44, "gpu_mem_mb": 3504 }, # after segment (after re-forward)
    
    {"node_id":45, "gpu_mem_mb": 7030 }, # pivot 2 (before start=3503)
    {"node_id":46, "gpu_mem_mb": 6246 }, # ReLU=6246
    {"node_id":47, "gpu_mem_mb": 5462 },
    {"node_id":48, "gpu_mem_mb": 3894 }, # use forward first
    
    {"node_id":49, "gpu_mem_mb": 3306 }, # after segment (after re-forward)
    
    {"node_id":50, "gpu_mem_mb": 6442 }, # pivot 1 (before start=3307)
    {"node_id":51, "gpu_mem_mb": 3306 },
    
    {"node_id":52, "gpu_mem_mb": 1739 }, # all done.
]
# print([ n['gpu_mem_mb'] for n in total_cp_algo])

total_cp_na = [
    {"node_id": 0, "gpu_mem_mb": 1681.824218}, # before forwarding.
    {"node_id": 1, "gpu_mem_mb": 5111.09},
    {"node_id": 2, "gpu_mem_mb": 3466.92},
    {"node_id": 3, "gpu_mem_mb": 3877.96},
    {"node_id": 4, "gpu_mem_mb": 5111.09},
    {"node_id": 5, "gpu_mem_mb": 4289.00},
    {"node_id": 6, "gpu_mem_mb": 4494.52},
    {"node_id": 7, "gpu_mem_mb": 5111.09},
    {"node_id": 8, "gpu_mem_mb": 4700.04},
    {"node_id": 9, "gpu_mem_mb": 5522.13},
    {"node_id":10, "gpu_mem_mb": 5522.13},
    {"node_id":11, "gpu_mem_mb": 4802.80},
    {"node_id":12, "gpu_mem_mb": 5213.85},
    {"node_id":13, "gpu_mem_mb": 5008.33},
    {"node_id":14, "gpu_mem_mb": 5419.37},
    {"node_id":15, "gpu_mem_mb": 5419.37},
    {"node_id":16, "gpu_mem_mb": 5059.71},
    {"node_id":17, "gpu_mem_mb": 5162.47},
    {"node_id":18, "gpu_mem_mb": 5111.09},
    {"node_id":19, "gpu_mem_mb": 5213.85},
    {"node_id":20, "gpu_mem_mb": 5213.85},
    {"node_id":21, "gpu_mem_mb": 5124.32},
]

# Prediction by algo.
# [1568, 1568, 392.0,
#  784.0, 784.0, 196.0,
#  392.0, 392.0, 392.0, 392.0,
#  98.0, 196.0, 196.0, 196.0, 196.0,
#  49.0, 49.0, 49.0, 49.0, 49.0, 12.0]
# + weight_all.
# 547.990966796875 MB = 76.365966796875 MB (conv) + ? MB (classifier)
# pytorch_memlab:
# Used Memory: 548.05M  Total Tensors: 143667240        

df_total = pd.DataFrame(total)
df_total_cp_algo = pd.DataFrame(total_cp_algo)
df_total_cp_na = pd.DataFrame(total_cp_na)
df_algo_predict = pd.DataFrame(algo_predict)
# df_activation = pd.DataFrame(activation)

l_total = alt.Chart(df_total).mark_line(color="#7d8597").transform_fold(
    ['gpu_mem_mb']
).encode(
    alt.X("node_id", axis=alt.Axis(tickMinStep=1)).title("Training Phase Index"),
    alt.Y("gpu_mem_mb", axis=alt.Axis(tickMinStep=100)).title("GPU Memory(MiB)"),
)


l_total_cp_algo = alt.Chart(df_total_cp_algo).mark_line(color="#0ead69").transform_fold(
    ['gpu_mem_mb']
).encode(
    alt.X("node_id", axis=alt.Axis(tickMinStep=1)).title("Training Phase Index"),
    alt.Y("gpu_mem_mb", axis=alt.Axis(tickMinStep=100)).title("GPU Memory(MiB)"),
)


l_total_cp_na = alt.Chart(df_total_cp_na).mark_line(color="#7678ed").transform_fold(
    ['gpu_mem_mb']
).encode(
    alt.X("node_id", axis=alt.Axis(tickMinStep=1)).title("Training Phase Index"),
    alt.Y("gpu_mem_mb", axis=alt.Axis(tickMinStep=100)).title("GPU Memory(MiB)"),
)


l_algo_predict = alt.Chart(df_algo_predict).mark_line(color="#7678ed").transform_fold(
    ['gpu_mem_mb']
).encode(
    alt.X("node_id", axis=alt.Axis(tickMinStep=1)).title("Training Phase Index"),
    alt.Y("gpu_mem_mb", axis=alt.Axis(tickMinStep=100)).title("GPU Memory(MiB)"),
)

# y_segment_cost = (
#     alt.Chart().mark_rule(strokeDash=[12, 6], size=2).encode(y=alt.datum(822))
# )

# bar = line.mark_bar()
point_total = l_total.mark_point(color="#333")
point_total_cp_algo = l_total_cp_algo.mark_point(color="#333")
point_total_cp_na = l_total_cp_na.mark_point(color="#333")
point_algo_predict = l_algo_predict.mark_point(color="#333")

(
    l_total_cp_algo + point_total_cp_algo
 # + l_total_cp_na + point_total_cp_na
 + l_total + point_total
    + l_algo_predict + point_algo_predict
).transform_fold(
    ['gpu_mem_mb'],
).properties(
    title="GPU Memory Usage: VGG19 with Gradient-Checkpointing Enabled",
    width=1500+250,
    height=900+150
)
# Out:
# 0-th node, 1644MB
# 1-th node, 3212MB
# 2-th node, 3212MB
# 3-th node, 3604MB
# 4-th node, 3996MB
# 5-th node, 3996MB
# 6-th node, 3408MB
# 7-th node, 3800MB
# 8-th node, 3800MB
# 9-th node, 3800MB
# 10-th node, 3800MB
# 11-th node, 3506MB
# 12-th node, 3604MB
# 13-th node, 3604MB
# 14-th node, 3604MB
# 15-th node, 3604MB
# 16-th node, 3457MB
# 17-th node, 3457MB
# 18-th node, 3457MB
# 19-th node, 3457MB
# 20-th node, 3457MB
# 21-th node, 3420MB
# 22-th node, 3410MB
# 23-th node, 3410MB
# 24-th node, 3408.48MB
# 25-th node, 3408.48MB
# 26-th node, 3408.48MB
# 27-th node, 6511.0MB
# 28-th node, 6507.0MB
# 29-th node, 6507.0MB
# 30-th node, 6495.0MB
# 31-th node, 6446.0MB
# 32-th node, 6397.0MB
# 33-th node, 6299.0MB
# 34-th node, 6299.0MB
# 35-th node, 6250.0MB
# 36-th node, 6054.0MB
# 37-th node, 5858.0MB
# 38-th node, 5466.0MB
# 39-th node, 5466.0MB
# 40-th node, 5368.23MB
# 41-th node, 4976.23MB
# 42-th node, 4584.23MB
# 43-th node, 3800.2299999999996MB
# 44-th node, 3408MB
# ...
